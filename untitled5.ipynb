# %% [markdown]
# <a href="https://colab.research.google.com/github/charan0416/DATA_ANALYSIS/blob/main/untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = pd.read_csv('/HistoricalPrices.csv')

# %%
data
# Out:
#         Date      Open      High       Low     Close
# 0   04/01/25  41879.75  42140.66  41519.90  41989.96
# 1   03/31/25  41382.52  42147.38  41148.13  42001.76
# 2   03/28/25  42245.82  42258.15  41530.00  41583.90
# 3   03/27/25  42432.96  42523.84  42142.19  42299.70
# 4   03/26/25  42655.85  42821.83  42326.67  42454.79
# ..       ...       ...       ...       ...       ...
# 56  01/08/25  42542.10  42656.22  42327.79  42635.20
# 57  01/07/25  42809.71  42931.54  42380.75  42528.36
# 58  01/06/25  42835.52  43115.31  42611.16  42706.56
# 59  01/03/25  42495.76  42782.76  42436.92  42732.13
# 60  01/02/25  42660.09  42905.09  42174.80  42392.27
#
# [61 rows x 5 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0[' Open'].plot(kind='hist', bins=20, title=' Open')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
data.head()
# Out:
#        Date      Open      High       Low     Close
# 0  04/01/25  41879.75  42140.66  41519.90  41989.96
# 1  03/31/25  41382.52  42147.38  41148.13  42001.76
# 2  03/28/25  42245.82  42258.15  41530.00  41583.90
# 3  03/27/25  42432.96  42523.84  42142.19  42299.70
# 4  03/26/25  42655.85  42821.83  42326.67  42454.79
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_15[' Open'].plot(kind='hist', bins=20, title=' Open')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_16[' High'].plot(kind='hist', bins=20, title=' High')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17[' Low'].plot(kind='hist', bins=20, title=' Low')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
data.describe()
# Out:
#                Open          High           Low         Close
# count     61.000000     61.000000     61.000000     61.000000
# mean   43220.486885  43455.676885  42936.131639  43219.484262
# std     1142.155729   1105.660573   1184.981375   1159.029933
# min    41057.570000  41360.120000  40661.770000  40813.570000
# 25%    42432.960000  42541.360000  42142.190000  42299.700000
# 50%    43259.840000  43323.490000  42927.760000  43191.240000
# 75%    44396.920000  44594.540000  44113.550000  44424.250000
# max    45054.360000  45054.360000  44621.960000  44882.130000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_35[' Open'].plot(kind='hist', bins=20, title=' Open')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_36[' High'].plot(kind='hist', bins=20, title=' High')
# ...

# %%
data.isnull()
# Out:
#      Date   Open   High    Low   Close
# 0   False  False  False  False   False
# 1   False  False  False  False   False
# 2   False  False  False  False   False
# 3   False  False  False  False   False
# 4   False  False  False  False   False
# ..    ...    ...    ...    ...     ...
# 56  False  False  False  False   False
# 57  False  False  False  False   False
# 58  False  False  False  False   False
# 59  False  False  False  False   False
# 60  False  False  False  False   False
#
# [61 rows x 5 columns]
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Date']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Date'}, axis=1)
# ...

# %%
data = data.rename(columns = {' Open': 'Open', ' High': 'High', ' Low': 'Low', ' Close': 'Close'})

# %%
data['Date'] = pd.to_datetime(data['Date'])
data =data.sort_values(by = 'Date')

# %%
data
# Out:
#          Date      Open      High       Low     Close
# 60 2025-01-02  42660.09  42905.09  42174.80  42392.27
# 59 2025-01-03  42495.76  42782.76  42436.92  42732.13
# 58 2025-01-06  42835.52  43115.31  42611.16  42706.56
# 57 2025-01-07  42809.71  42931.54  42380.75  42528.36
# 56 2025-01-08  42542.10  42656.22  42327.79  42635.20
# ..        ...       ...       ...       ...       ...
# 4  2025-03-26  42655.85  42821.83  42326.67  42454.79
# 3  2025-03-27  42432.96  42523.84  42142.19  42299.70
# 2  2025-03-28  42245.82  42258.15  41530.00  41583.90
# 1  2025-03-31  41382.52  42147.38  41148.13  42001.76
# 0  2025-04-01  41879.75  42140.66  41519.90  41989.96
#
# [61 rows x 5 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# data['Open'].plot(kind='hist', bins=20, title='Open')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

# %%
plt.plot(data['Date'],data['Close'])
plt.show()

# %%
plt.plot(data['Date'], data['Open'])
plt.plot(data['Date'], data['Close'])


plt.show()

# %%
plt.plot(data['Date'], data['Open'])
plt.plot(data['Date'], data['Close'])
plt.legend(['Open','Close'])
plt.title('historical prices')
plt.show()

# %%
Data = data.head(5)
plt.bar(Data['Date'],height=Data['High'])

plt.show()

# %%
plt.barh(Data['Date'],width=Data['High'])

plt.show()

# %%
plt.scatter(data['Open'],data['Close'])
plt.title('scatter plot of historical prices')
plt.show()

# %%
plt.plot(data['Date'], data['Open'], color = 'black')
plt.plot(data['Date'], data['Close'], color = 'red')
plt.legend(['Open','Close'])
plt.title('historical prices')
plt.show()

# %%
plt.plot_date(data['Date'], data['Open'], color = 'black')
plt.plot_date(data['Date'], data['Close'], color = 'red')
plt.legend(['Open','Close'])
plt.title('historical prices')
plt.show()
# Out:
# <ipython-input-42-91fc82d84d08>:1: MatplotlibDeprecationWarning: The plot_date function was deprecated in Matplotlib 3.9 and will be removed in 3.11. Use plot instead.
#   plt.plot_date(data['Date'], data['Open'], color = 'black')
# <ipython-input-42-91fc82d84d08>:2: MatplotlibDeprecationWarning: The plot_date function was deprecated in Matplotlib 3.9 and will be removed in 3.11. Use plot instead.
#   plt.plot_date(data['Date'], data['Close'], color = 'red')

# %%
plt.pie(Data['Open'], labels = Data['Date'])
# Out:
# ([<matplotlib.patches.Wedge at 0x79ee960760d0>,
# ...
#  [Text(0.8900000681454663, 0.6464517605367517, '2025-01-02 00:00:00'),
#   Text(-0.3369908001247616, 1.047108972662957, '2025-01-03 00:00:00'),
#   Text(-1.0999954199091198, 0.0031742997588937822, '2025-01-06 00:00:00'),
#   Text(-0.338193334117325, -1.046721199154105, '2025-01-07 00:00:00'),
#   Text(0.891121954113542, -0.6449043827551978, '2025-01-08 00:00:00')])

# %%
plt.pie(Data['Open'], labels = Data['Close'], autopct = '%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x79ee95f3f610>,
# ...
#  [Text(0.8900000681454663, 0.6464517605367517, '42392.27'),
#   Text(-0.3369908001247616, 1.047108972662957, '42732.13'),
#   Text(-1.0999954199091198, 0.0031742997588937822, '42706.56'),
#   Text(-0.338193334117325, -1.046721199154105, '42528.36'),
#   Text(0.891121954113542, -0.6449043827551978, '42635.2')],
#  [Text(0.4854545826247997, 0.35261005120186456, '20.0%'),
#   Text(-0.18381316370441542, 0.5711503487252492, '19.9%'),
#   Text(-0.5999975017686108, 0.001731436232123881, '20.1%'),
#   Text(-0.1844690913367227, -0.570938835902239, '20.1%'),
#   Text(0.4860665204255683, -0.3517660269573806, '19.9%')])

# %%
plt.hist(data['Open'])
plt.show()

# %%
plt.hist(data['Close'], bins = 10)
plt.show()

# %%
plt.boxplot(data['Low'])
plt.show()
# Out:
# <ipython-input-102-704491fe9f73>:1: MatplotlibDeprecationWarning: Passing the notch parameter of boxplot() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.boxplot(data['Low'],data['High'])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-102-704491fe9f73> in <cell line: 0>()
# ----> 1 plt.boxplot(data['Low'],data['High'])
#       2 plt.show()
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#     454
#     455     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# ...

# %%
plt.scatter(data['Open'],data['Close'], c=data['Close'], cmap = plt.cm.plasma)

plt.show()

# %%
plt.scatter(data['Open'],data['Close'], c=data['Close'], cmap = plt.cm.plasma)
plt.colorbar()
plt.show()

# %%
plt.scatter(data['Open'],data['Close'], c=data['Close'], cmap = plt.cm.plasma)
plt.colorbar()
plt.xlabel('Open')
plt.ylabel('Close')
plt.show()

# %%
plt.draw()

# %%
prices = data.sort_values(by = 'High')

# %%
prices
# Out:
#          Date      Open      High       Low     Close
# 13 2025-03-13  41280.05  41360.12  40661.77  40813.57
# 12 2025-03-14  41057.57  41528.11  40929.54  41488.19
# 14 2025-03-12  41577.50  41721.36  41010.24  41350.93
# 10 2025-03-18  41772.91  41787.25  41415.43  41581.31
# 15 2025-03-11  41837.95  41868.27  41175.37  41433.48
# ..        ...       ...       ...       ...       ...
# 43 2025-01-29  44819.55  44962.58  44579.10  44713.52
# 37 2025-02-06  44949.19  44966.63  44545.27  44747.63
# 44 2025-01-28  44756.36  44976.35  44621.96  44850.35
# 42 2025-01-30  44548.69  45008.75  44548.69  44882.13
# 41 2025-01-31  45054.36  45054.36  44507.22  44544.66
#
# [61 rows x 5 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# prices['Open'].plot(kind='hist', bins=20, title='Open')
# ...

# %%
plt.plot(prices['Date'], prices['High'])
plt.title('Daily High Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
plt.barh(prices['Date'], prices['High'])
plt.title('Daily High Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.violinplot(prices['High'])
plt.title('Daily High Prices')
plt.show()

# %%
plt.barh(prices['Date'], prices['High'])
plt.title('Daily High Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()
